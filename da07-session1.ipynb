# %% [markdown]
# # DA07 PYTHON PROGRAMMING JOURNEY

# %% [markdown]
# #### DEMONSTRATING BASICS IN PYTHON

# %%
a=2
b=10
a+b;

# %%
print("data analytics")
# Out:
# data analytics

# %%
#Declaring a static value
val1 = "DATA"

# %%
print(type(val1))
# Out:
# <class 'str'>

# %%
#Declaring a Dynamic value
fname = input("Enter your first name : ")
lname = input("Enter your last name : ")
print("Welcome", fname, lname)
# Out:
# Enter your first name :  Bhanu
# Enter your last name :  D
# Welcome Bhanu D

# %%
name = input("Enter your name: ")
job_name = input("Enter your target job role: ")
adjective = input("Describe your cohort: ")
food1 = input("What did you eat first: ")
food2 = input("What else did you eat: ")
feeling = input("How do you feel: ")
print("Hi, I am "+ name + " and I am doing a training targeting a " +job_name+ " role."
      "I found this cohort to be very" + adjective + "."
      "For lunch I had " +food1+ " and " +food2+ " while reviewing their notes."
      "I feel " +feeling+ " but am determined to complete the course.")

# %%
# int a = 10

# %% [markdown]
# ## Understanding Different Data Types

# %%
ivar = 10

# %%
print(ivar)
# Out:
# 10

# %%
print(type(ivar))
# Out:
# <class 'int'>

# %%
fvar = 25.12

# %%
print(type(fvar))
# Out:
# <class 'float'>

# %%
svar = "DA"

# %%
print(type(svar))
# Out:
# <class 'str'>

# %%
bvar = True

# %%
print(type(bvar))
# Out:
# <class 'bool'>

# %%
a = 12
b = 15.63
c = a+b

# %%
print(c)
# Out:
# 27.630000000000003

# %%
print(type(c))
# Out:
# <class 'float'>

# %%
x = 23
y = "Data"
z = x+y
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 x = 23
#       2 y = "Data"
# ----> 3 z = x+y
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x = 23
y = "Data"
z = str(x)+y

# %%
print(z)
# Out:
# 23Data

# %%
 #Dem lists
lvar = [56, "Data", 36.21, "Hello", 12]

# %%
print(lvar)
# Out:
# [56, 'Data', 36.21, 'Hello', 12]

# %%
print(type(lvar))
# Out:
# <class 'list'>

# %%
lvar[3]
# Out:
# 'Hello'

# %%
lvar.append("Analytics")

# %%
print(lvar)
# Out:
# [56, 'Data', 36.21, 'Hello', 12, 'Analytics']

# %%
lvar.insert(1,"Hi")

# %%
print(lvar)
# Out:
# [56, 'Hi', 'Hi', 'Hi', 'Data', 'Hi', 36.21, 'Hello', 12, 'Analytics']

# %%
lvar[4:8]
# Out:
# ['Data', 'Hi', 36.21, 'Hello']

# %%
lvar[1:]
# Out:
# ['Hi', 'Hi', 'Hi', 'Data', 'Hi', 36.21, 'Hello', 12, 'Analytics']

# %%
lvar[:6]
# Out:
# [56, 'Hi', 'Hi', 'Hi', 'Data', 'Hi']

# %%
lvar.sort()
